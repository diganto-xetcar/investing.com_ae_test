# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2023-12-01  27.000000  28.014999  26.510000  27.740000  27.639784  5455100
# 2023-12-04  27.280001  27.930000  26.764999  26.809999  26.713142  4965000
# 2023-12-05  26.500000  26.530001  25.129999  25.240000  25.148815  7715800
# 2023-12-06  25.600000  25.959999  25.040001  25.120001  25.029249  4055000
# 2023-12-07  25.160000  25.290001  24.270000  24.940001  24.849899  6780000
# ...               ...        ...        ...        ...        ...      ...
# 2024-03-25  31.570000  32.299999  31.500000  31.860001  31.860001  4745000
# 2024-03-26  32.320000  32.320000  31.230000  31.580000  31.580000  3765000
# 2024-03-27  31.719999  33.230000  31.670000  33.209999  33.209999  6439000
# 2024-03-28  33.240002  33.965000  33.200001  33.790001  33.790001  6147100
# 2024-04-01  34.099998  34.360001  33.509998  34.020000  34.020000  4440200
#
# [82 rows x 6 columns]

# %%
AA_ret_1 = AA_1['Adj Close'][-1]/AA_1['Adj Close'][0]

# %%
AA_ret_2 = AA_2['Adj Close'][-1]/AA_2['Adj Close'][0]

# %%
AA_ret_3 = AA_3['Adj Close'][-1]/AA_3['Adj Close'][0]

# %%
AA_ret_4 = AA_4['Adj Close'][-1]/AA_4['Adj Close'][0]

# %%
AA_total_ret = (AA_ret_1*
                AA_ret_2*
                AA_ret_3*
                AA_ret_4)**(1/(9/12)) - 1

# %%
AA_total_ret
# Out:
# -0.056080758134852915

# %%
# Source: https://www.investing.com/indices/dj-aluminum-historical-data
# Checked: Correct 
AA_djusal_1 = 139.65/127.73
AA_djusal_1

# Checked: Correct
AA_djusal_2 = 127.32/186.45
AA_djusal_2

# Checked: Correct
AA_djusal_3 = 115.91/111.71
AA_djusal_3

# Checked: Correct
AA_djusal_4 = 116.22/94.76
AA_djusal_4

AA_djusal_ret = (AA_djusal_1*
                 AA_djusal_2*
                 AA_djusal_3*
                 AA_djusal_4)**(1/(9/12)) - 1
AA_djusal_ret
# Out:
# -0.06598054100966122

# %%
LLY_1 = pdr.get_data_yahoo('LLY', start='2022-11-01', end='2022-12-02')
LLY_2 = pdr.get_data_yahoo('LLY', start='2022-09-01', end='2022-10-02')
LLY_3 = pdr.get_data_yahoo('LLY', start='2023-04-01', end='2023-05-02')
LLY_4 = pdr.get_data_yahoo('LLY', start='2024-01-01', end='2024-03-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
LLY_1
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-11-01  345.829987  358.989990  340.750000  352.579987  347.555878
# 2022-11-02  354.160004  363.149994  350.209991  354.959991  349.901947
# 2022-11-03  354.059998  362.829987  351.510010  361.679993  356.526215
# 2022-11-04  365.200012  365.880005  353.339996  357.410004  352.317047
# 2022-11-07  358.000000  367.000000  357.500000  365.070007  359.867920
# 2022-11-08  365.149994  368.750000  361.929993  366.660004  361.435211
# 2022-11-09  368.440002  369.799988  361.910004  363.269989  358.093536
# 2022-11-10  367.239990  369.000000  363.000000  368.720001  363.465912
# 2022-11-11  366.160004  367.829987  344.519989  352.299988  347.279877
# 2022-11-14  359.070007  360.799988  340.119995  356.059998  351.965332
# 2022-11-15  356.940002  356.989990  346.359985  349.950012  345.925629
# 2022-11-16  350.000000  356.880005  349.959991  352.929993  348.871368
# ...

# %%
LLY_2
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-09
LLY_ret_4 = LLY_4['Adj Close'][-1]/LLY_4['Adj Close'][0]

LLY_total_ret = (LLY_ret_1*
                 LLY_ret_2*
                 LLY_ret_3*
                 LLY_ret_4)**(1/(5/12))-1

# %%
LLY_total_ret
# Out:
# 2.5054329771944928

# %%
# Source: https://www.investing.com/indices/dj-pharmaceuticals-historical-data
LLY_djuspr_2 = 749.3/761.23

LLY_djuspr_1 = 857.38/814.43

LLY_djuspr_3 = 812.43/776.59

LLY_djuspr_4 = 930.04/838.26

LLY_djuspr_ret = (LLY_djuspr_1*
                  LLY_djuspr_2*
                  LLY_djuspr_3*
                  LLY_djuspr_4)**(1/(5/12))-1
LLY_djuspr_ret
# Out:
# 0.5574837238272243

# %%
OXY_1 = pdr.get_data_yahoo('OXY', start='2023-03-01', end='2024-02-02')
OXY_2 = pdr.get_data_yahoo('OXY', start='2022-03-01', end='2022-11-02')
OXY_3 = pdr.get_data_yahoo('OXY', start='2021-08-01', end='2021-12-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
OXY_1
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2023-03-01  58.509998  60.090000  58.400002  59.709999  58.794479  14414200
# 2023-03-02  59.400002  60.540001  59.250000  60.270000  59.345890  13858700
# 2023-03-03  59.480000  61.700001  59.310001  61.250000  60.310867  17088900
# 2023-03-06  61.060001  61.970001  60.849998  61.680000  60.734272  12890800
# 2023-03-07  61.320000  61.650002  60.500000  60.849998  59.917000  12547300
# ...               ...        ...        ...        ...        ...       ...
# 2024-01-26  58.230000  58.430000  57.540001  58.400002  58.189690   7102800
# 2024-01-29  58.349998  58.419998  57.610001  58.220001  58.010338   7175800
# 2024-01-30  57.750000  58.990002  57.750000  58.900002  58.687889   8337500
# 2024-01-31  58.790001  58.860001  57.560001  57.570000  57.362675   8941900
# 2024-02-01  57.910000  58.110001  56.919998  57.320000  57.113575  11277700
#
# [233 rows x 6 columns]

# %%
OXY_2
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2022-03-01  44.330002  47.830002  44.040001  46.790001  45.690590   68949800
# 2022-03-02  48.529999  49.290001  47.020000  48.369999  47.233459   51230100
# 2022-03-03  47.869999  48.669998  47.070000  47.750000  46.628036   43690500
# 2022-03-04  48.459999  56.450001  48.139999  56.150002  54.830666  101631900
# 2022-03-07  57.709999  58.770000  52.410000  55.380001  54.078758   81361200
# ...               ...        ...        ...        ...        ...        ...
# 2022-10-26  71.599998  73.290001  71.500000  72.519997  71.262352   12722000
# 2022-10-27  73.589996  74.169998  71.760002  71.870003  70.623634   12754100
# 2022-10-28  72.489998  73.279999  69.849998  71.839996  70.594147   13814400
# 2022-10-31  71.199997  74.129997  71.099998  72.599998  71.340965   13646400
# 2022-11-01  74.019997  74.489998  73.160004  73.800003  72.520164   13011800
#
# [171 rows x 6 columns]

# %%
OXY_3
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-08-02  26.100000  27.059999  25.719999  25.790001  25.165731  13880000
# 2021-08-03  25.490000  26.500000  25.219999  26.430000  25.790239  15215300
# 2021-08-04  25.980000  26.889999  25.440001  25.690001  25.068151  20780200
# 2021-08-05  25.940001  26.830000  25.879999  26.190001  25.556049  12976200
# 2021-08-06  26.680000  27.080000  26.230000  26.389999  25.751209  12862500
# ...               ...        ...        ...        ...        ...       ...
# 2021-11-24  31.430000  32.480000  31.389999  32.009998  31.247709  11491000
# 2021-11-26  29.340000  29.879999  27.850000  29.700001  28.992722  22787800
# 2021-11-29  30.799999  31.270000  29.610001  30.059999  29.344149  15448100
# 2021-11-30  29.100000  29.969999  29.020000  29.650000  28.943916  20779600
# 2021-12-01  30.690001  30.969999  28.910000  28.950001  28.260586  19000400
#
# [86 rows x 6 columns]

# %%
OXY_ret_1 = OXY_1['Adj Close'][-1]/OXY_1['Adj Close'][0]

OXY_ret_2 = OXY_2['Adj Close'][-1]/OXY_2['Adj Close'][0]

OXY_ret_3 = OXY_3['Adj Close'][-1]/OXY_3['Adj Close'][0]

OXY_total_ret = (OXY_ret_1*
                 OXY_ret_2*
                 OXY_ret_3)**(1/(23/12))-1

# %%
OXY_total_ret
# Out:
# 0.33163731076508496

# %%
# Source: https://www.investing.com/indices/dj-oil---gas-historical-data

OXY_djusen_1 = 688.51/706.76

OXY_djusen_2 = 759.02/588.43

OXY_djusen_3 = 451.21/409.09

OXY_djusen_ret = (OXY_djusen_1*
                  OXY_djusen_2*
                  OXY_djusen_3)**(1/(23/12))-1

# %%
OXY_djusen_ret
# Out:
# 0.1856593826250439

# %%
AA_final_df = pdr.get_data_yahoo('AA', start='2022-10-01', end='2024-04-28')
LLY_final_df = pdr.get_data_yahoo('LLY', start='2022-09-01', end='2024-04-28')
OXY_final_df = pdr.get_data_yahoo('OXY', start='2021-08-01', end='2024-04-28')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Date of e-mail
end_date = date(2024,4,27)

# Date of initial entry into stock 
AA_start_date = date(2022,10,1)
LLY_start_date = date(2022,9,1)
OXY_start_date = date(2021,8,1)


AA_days = end_date - AA_start_date
LLY_days = end_date - LLY_start_date
OXY_days = end_date - OXY_start_date

AA_ret_final = (AA_final_df['Adj Close'][-1]/
                AA_final_df['Adj Close'][0])**(1/(AA_days.days/365))-1
LLY_ret_final = (LLY_final_df['Adj Close'][-1]/
                 LLY_final_df['Adj Close'][0])**(1/(LLY_days.days/365))-1
OXY_ret_final = (OXY_final_df['Adj Close'][-1]/
                 OXY_final_df['Adj Close'][0])**(1/(OXY_days.days/365))-1

# %%
AA_ret_final
# Out:
# 0.0027171585815222166

# %%
LLY_ret_final
# Out:
# 0.7003604946181436

# %%
OXY_ret_final
# Out:
# 0.4356764605142762

# %%
AA_djusal_final_ret = (125.99/127.73)**(1/(AA_days.days/365))-1
AA_djusal_final_ret
# Out:
# -0.008683998837810236

# %%
LLY_djuspr_final_ret = (874.63/761.23)**(1/(LLY_days.days/365))-1
LLY_djuspr_final_ret
# Out:
# 0.08753862560796977

# %%
OXY_djusen_final_ret = (791.95/409.09)**(1/(OXY_days.days/365))-1
OXY_djusen_final_ret
# Out:
# 0.27265532312325336

# %%
OXY_days.days/365
# Out:
# 2.73972602739726
